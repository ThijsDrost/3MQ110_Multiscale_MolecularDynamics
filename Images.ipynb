# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({'font.size': 14})

base_loc = r'D:\Uni\Master\Mulitscale_methods\MD\Tex\images'
def imloc(end: str):
    return rf'{base_loc}\{end}'

# %%
x = np.linspace(0.1, 10, 1000)
lennard = 4*(x**(-12.0)-x**(-6))
lennard_diff = 24*(x**(-7)-2*x**(-13.0))

plt.figure()
plt.plot(x, lennard, label='$V_{LJ}$')
plt.plot(x, lennard_diff, label=r'$\frac{d}{dx}V_{LJ}$')
plt.ylim(-2.5, 2.5)
plt.xlim(0.75, 4)
plt.ylabel(r'$y (\epsilon)$')
plt.xlabel('r')
plt.grid()
plt.legend()
plt.savefig(imloc('lennard.png'))
plt.show()

print(2**(1/6))
# Out:
# 1.122462048309373
